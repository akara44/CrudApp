-- %% [markdown]
-- # [EgitimKampiDb]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [EgitimKampiDb]    Script Date: 21.07.2025 09:38:03 ******/
CREATE DATABASE [EgitimKampiDb]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'EgitimKampiDb', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\EgitimKampiDb.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'EgitimKampiDb_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\EgitimKampiDb_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [EgitimKampiDb] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [EgitimKampiDb].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [EgitimKampiDb] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET ARITHABORT OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [EgitimKampiDb] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [EgitimKampiDb] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET  DISABLE_BROKER 
GO
ALTER DATABASE [EgitimKampiDb] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [EgitimKampiDb] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [EgitimKampiDb] SET  MULTI_USER 
GO
ALTER DATABASE [EgitimKampiDb] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [EgitimKampiDb] SET DB_CHAINING OFF 
GO
ALTER DATABASE [EgitimKampiDb] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [EgitimKampiDb] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [EgitimKampiDb] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [EgitimKampiDb] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [EgitimKampiDb] SET QUERY_STORE = ON
GO
ALTER DATABASE [EgitimKampiDb] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[TblCategory]

-- %%
USE [EgitimKampiDb]
GO

-- %%
/****** Object:  Table [dbo].[TblCategory]    Script Date: 21.07.2025 09:38:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblCategory](
	[CategoryId] [int] IDENTITY(1,1) NOT NULL,
	[CategoryName] [nvarchar](50) NULL,
 CONSTRAINT [PK_TblCategory] PRIMARY KEY CLUSTERED 
(
	[CategoryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblOrder]

-- %%
/****** Object:  Table [dbo].[TblOrder]    Script Date: 21.07.2025 09:38:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblOrder](
	[OrderId] [int] IDENTITY(1,1) NOT NULL,
	[OrderCustomer] [varchar](50) NULL,
	[ProductCount] [tinyint] NULL,
	[ProductUnitPrice] [decimal](18, 2) NULL,
	[TotalPrice] [decimal](18, 2) NULL,
 CONSTRAINT [PK_TblOrder] PRIMARY KEY CLUSTERED 
(
	[OrderId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblProduct]

-- %%
/****** Object:  Table [dbo].[TblProduct]    Script Date: 21.07.2025 09:38:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblProduct](
	[ProductId] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [varchar](50) NULL,
	[ProductPrice] [decimal](18, 2) NULL,
	[ProductStatus] [bit] NULL,
 CONSTRAINT [PK_TblProduct] PRIMARY KEY CLUSTERED 
(
	[ProductId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [EgitimKampiDb]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [EgitimKampiDb] SET  READ_WRITE 
GO
